# %%
import pandas as pd
import numpy as np
import math

# %%
X = df.iloc[:, :-1]   # features
y = df.iloc[:, -1]    # class

print(X.shape, y.shape)
# Out:
# (768, 8) (768,)

# %%
df[y.name].value_counts()

total = len(df)

P_yes = (df[y.name] == "Yes").sum() / total
P_no  = (df[y.name] == "No").sum() / total

print("P(Yes) =", P_yes)
print("P(No)  =", P_no)
# Out:
# P(Yes) = 0.0
# P(No)  = 0.0

# %%
pd.crosstab(df['feature1'], df[y.name])
